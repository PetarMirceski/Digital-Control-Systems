# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn, optim
from torchvision import transforms, datasets, models
from torch.utils.data.sampler import SubsetRandomSampler

import os

images = "./cell_images/"
parasite_folder = "Parasitized"
unparasite_folder = "Uninfected"
print(os.listdir(images))
# Out:
# ['Parasitized', 'Uninfected']

# %% [markdown]
# # Listing the paths
# loading image names and removing excess files

# %%
parasite_images_name = os.listdir(images + parasite_folder)
unparasite_images_name = os.listdir(images + unparasite_folder)
parasite_images_name.remove("Thumbs.db")
unparasite_images_name.remove("Thumbs.db")

# %%
parasite_images_name = np.array(parasite_images_name)
unparasite_images_name = np.array(unparasite_images_name)

# %% [markdown]
# # The Dataset is balanced we have 13779 positives and 13779 negatives

# %%
parasite_images_name.shape, unparasite_images_name.shape
# Out:
# ((13779,), (13779,))

# %% [markdown]
# # Constructing the labels for the images

# %%
parasite_labels = np.ones(parasite_images_name.shape)
unparasite_labels = np.zeros(unparasite_images_name.shape)

# %%
parasite_labels, unparasite_labels, parasite_labels.shape, unparasite_labels.shape
# Out:
# (array([1., 1., 1., ..., 1., 1., 1.]),
#  array([0., 0., 0., ..., 0., 0., 0.]),
#  (13779,),
#  (13779,))

# %%
parasite_data = pd.DataFrame()

# %% [markdown]
# # Loading the full path to the images

# %%
parasite_data['name'] = parasite_images_name
parasite_data['label'] = parasite_labels
parasite_data_pure_names = parasite_data.copy()
parasite_data['name'] = './cell_images/Parasitized/'+ parasite_data['name']

# %%
parasite_data.head()
# Out:
#                                                 name  label
# 0  ./cell_images/Parasitized/C100P61ThinF_IMG_201...    1.0
# 1  ./cell_images/Parasitized/C100P61ThinF_IMG_201...    1.0
# 2  ./cell_images/Parasitized/C100P61ThinF_IMG_201...    1.0
# 3  ./cell_images/Parasitized/C100P61ThinF_IMG_201...    1.0
# 4  ./cell_images/Parasitized/C100P61ThinF_IMG_201...    1.0

# %%
unparasite_data = pd.DataFrame()

# %%
unparasite_data['name'] = unparasite_images_name
unparasite_data['label'] = unparasite_labels
unparasite_data_pure_names = unparasite_data.copy()
unparasite_data['name'] = './cell_images/Uninfected/'+ unparasite_data['name']

# %%
unparasite_data.head()
# Out:
#                                                 name  label
# 0  ./cell_images/Uninfected/C100P61ThinF_IMG_2015...    0.0
# 1  ./cell_images/Uninfected/C100P61ThinF_IMG_2015...    0.0
# 2  ./cell_images/Uninfected/C100P61ThinF_IMG_2015...    0.0
# 3  ./cell_images/Uninfected/C100P61ThinF_IMG_2015...    0.0
# 4  ./cell_images/Uninfected/C100P61ThinF_IMG_2015...    0.0

# %% [markdown]
# # Shuffling the DataSet

# %%
# Shuffle images 
frames = [parasite_data, unparasite_data]
data = pd.concat(frames)
data = data.sample(frac=1).reset_index(drop=True)

# %%
data_values = data.values

# %% [markdown]
# # Dividing the Data into Train/Validation set and Test Set

# %%
test_split = 0.1
train_data_size  = int(np.floor(data_values.shape[0] * (test_split)))

# %%
split_index = data_values.shape[0] - train_data_size

# %%
train_val_values = data_values[0:split_index,:]

# %%
test_values = data_values[split_index :,:]

# %%
train_val_df  = pd.DataFrame()

# %%
train_val_df['name'] = train_val_values[:,0]
train_val_df['label'] = train_val_values[:,1]

# %%
test_df = pd.DataFrame()
test_df['name'] = test_values[:,0]
test_df['label'] = test_values[:,1]

# %%
train_val_df
# Out:
#                                                     name label
# 0      ./cell_images/Uninfected/C228ThinF_IMG_2015111...     0
# 1      ./cell_images/Parasitized/C184P145ThinF_IMG_20...     1
# 2      ./cell_images/Parasitized/C81P42ThinF_IMG_2015...     1
# 3      ./cell_images/Uninfected/C171P132ThinF_IMG_201...     0
# 4      ./cell_images/Uninfected/C84P45ThinF_IMG_20150...     0
# 5      ./cell_images/Uninfected/C84P45ThinF_IMG_20150...     0
# 6      ./cell_images/Uninfected/C51AP12thinF_IMG_2015...     0
# 7      ./cell_images/Parasitized/C63P24N_ThinF_IMG_20...     1
# 8      ./cell_images/Parasitized/C116P77ThinF_IMG_201...     1
# 9      ./cell_images/Uninfected/C50P11thinF_IMG_20150...     0
# 10     ./cell_images/Uninfected/C183P144NThinF_IMG_20...     0
# 11     ./cell_images/Parasitized/C140P101ThinF_IMG_20...     1
# 12     ./cell_images/Parasitized/C159P120ThinF_IMG_20...     1
# 13     ./cell_images/Parasitized/C136P97ThinF_IMG_201...     1
# 14     ./cell_images/Uninfected/C217ThinF_IMG_2015110...     0
# 15     ./cell_images/Uninfected/C71P32_ThinF_IMG_2015...     0
# 16     ./cell_images/Uninfected/C4thin_original_IMG_2...     0
# 17     ./cell_images/Parasitized/C137P98ThinF_IMG_201...     1
# 18     ./cell_images/Uninfected/C179P140ThinF_IMG_201...     0
# 19     ./cell_images/Parasitized/C174P135NThinF_IMG_2...     1
# 20     ./cell_images/Parasitized/C184P145ThinF_IMG_20...     1
# 21     ./cell_images/Uninfected/C47P8thin_Original_Mo...     0
# 22     ./cell_images/Parasitized/C39P4thinF_original_...     1
# 23     ./cell_images/Parasitized/C99P60ThinF_IMG_2015...     1
# 24     ./cell_images/Uninfected/C187P148NThinF_IMG_20...     0
# 25     ./cell_images/Uninfected/C144P105ThinF_IMG_201...     0
# 26     ./cell_images/Uninfected/C233ThinF_IMG_2015111...     0
# 27     ./cell_images/Uninfected/C131P92ThinF_IMG_2015...     0
# 28     ./cell_images/Parasitized/C116P77ThinF_IMG_201...     1
# 29     ./cell_images/Uninfected/C103P64ThinF_IMG_2015...     0
# ...                                                  ...   ...
# 24773  ./cell_images/Uninfected/C238NThinF_IMG_201512...     0
# 24774  ./cell_images/Parasitized/C116P77ThinF_IMG_201...     1
# 24775  ./cell_images/Uninfected/C69P30N_ThinF_IMG_201...     0
# 24776  ./cell_images/Parasitized/C118P79ThinF_IMG_201...     1
# 24777  ./cell_images/Parasitized/C158P119ThinF_IMG_20...     1
# 24778  ./cell_images/Parasitized/C180P141NThinF_IMG_2...     1
# 24779  ./cell_images/Parasitized/C59P20thinF_IMG_2015...     1
# 24780  ./cell_images/Uninfected/C135P96ThinF_IMG_2015...     0
# 24781  ./cell_images/Parasitized/C132P93ThinF_IMG_201...     1
# 24782  ./cell_images/Parasitized/C131P92ThinF_IMG_201...     1
# 24783  ./cell_images/Uninfected/C205ThinF_IMG_2015110...     0
# 24784  ./cell_images/Parasitized/C100P61ThinF_IMG_201...     1
# 24785  ./cell_images/Parasitized/C133P94ThinF_IMG_201...     1
# 24786  ./cell_images/Uninfected/C1_thinF_IMG_20150604...     0
# 24787  ./cell_images/Parasitized/C99P60ThinF_IMG_2015...     1
# 24788  ./cell_images/Parasitized/C93P54ThinF_IMG_2015...     1
# 24789  ./cell_images/Uninfected/C163P124ThinF_IMG_201...     0
# 24790  ./cell_images/Parasitized/C180P141NThinF_IMG_2...     1
# 24791  ./cell_images/Parasitized/C188P149ThinF_IMG_20...     1
# 24792  ./cell_images/Uninfected/C45P6ThinF_IMG_201511...     0
# 24793  ./cell_images/Parasitized/C176P137NThinF_IMG_2...     1
# 24794  ./cell_images/Uninfected/C92P53ThinF_IMG_20150...     0
# 24795  ./cell_images/Uninfected/C168P129ThinF_IMG_201...     0
# 24796  ./cell_images/Parasitized/C48P9thinF_IMG_20150...     1
# 24797  ./cell_images/Parasitized/C118P79ThinF_IMG_201...     1
# 24798  ./cell_images/Uninfected/C83P44ThinF_IMG_20150...     0
# 24799  ./cell_images/Uninfected/C55P16thinF_IMG_20150...     0
# 24800  ./cell_images/Parasitized/C129P90ThinF_IMG_201...     1
# 24801  ./cell_images/Uninfected/C56P17thinF_IMG_20150...     0
# 24802  ./cell_images/Uninfected/C124P85ThinF_IMG_2015...     0
#
# [24803 rows x 2 columns]

# %%
test_df
# Out:
#                                                    name label
# 0     ./cell_images/Parasitized/C189P150ThinF_IMG_20...     1
# 1     ./cell_images/Parasitized/C132P93ThinF_IMG_201...     1
# 2     ./cell_images/Uninfected/C203ThinF_IMG_2015102...     0
# 3     ./cell_images/Parasitized/C68P29N_ThinF_IMG_20...     1
# 4     ./cell_images/Parasitized/C141P102ThinF_IMG_20...     1
# 5     ./cell_images/Uninfected/C78P39ThinF_IMG_20150...     0
# 6     ./cell_images/Parasitized/C59P20thinF_IMG_2015...     1
# 7     ./cell_images/Parasitized/C174P135NThinF_IMG_2...     1
# 8     ./cell_images/Uninfected/C203ThinF_IMG_2015102...     0
# 9     ./cell_images/Uninfected/C213ThinF_IMG_2015110...     0
# 10    ./cell_images/Uninfected/C224ThinF_IMG_2015111...     0
# 11    ./cell_images/Uninfected/C7NthinF_IMG_20150611...     0
# 12    ./cell_images/Parasitized/C118P79ThinF_IMG_201...     1
# 13    ./cell_images/Parasitized/C180P141NThinF_IMG_2...     1
# 14    ./cell_images/Parasitized/C180P141NThinF_IMG_2...     1
# 15    ./cell_images/Parasitized/C157P118ThinF_IMG_20...     1
# 16    ./cell_images/Uninfected/C167P128ReThinF_IMG_2...     0
# 17    ./cell_images/Uninfected/C109P70ThinF_IMG_2015...     0
# 18    ./cell_images/Parasitized/C39P4thinF_original_...     1
# 19    ./cell_images/Parasitized/C189P150ThinF_IMG_20...     1
# 20    ./cell_images/Parasitized/C68P29N_ThinF_IMG_20...     1
# 21    ./cell_images/Parasitized/C128P89ThinF_IMG_201...     1
# 22    ./cell_images/Parasitized/C59P20thinF_IMG_2015...     1
# 23    ./cell_images/Parasitized/C132P93ThinF_IMG_201...     1
# 24    ./cell_images/Parasitized/C51AP12thinF_IMG_201...     1
# 25    ./cell_images/Uninfected/C48P9thinF_IMG_201507...     0
# 26    ./cell_images/Parasitized/C39P4thinF_original_...     1
# 27    ./cell_images/Uninfected/C1_thinF_IMG_20150604...     0
# 28    ./cell_images/Parasitized/C59P20thinF_IMG_2015...     1
# 29    ./cell_images/Uninfected/C45P6ThinF_IMG_201511...     0
# ...                                                 ...   ...
# 2725  ./cell_images/Parasitized/C68P29N_ThinF_IMG_20...     1
# 2726  ./cell_images/Uninfected/C160P121ThinF_IMG_201...     0
# 2727  ./cell_images/Parasitized/C189P150ThinF_IMG_20...     1
# 2728  ./cell_images/Uninfected/C81P42ThinF_IMG_20150...     0
# 2729  ./cell_images/Parasitized/C111P72ThinF_IMG_201...     1
# 2730  ./cell_images/Uninfected/C129P90ThinF_IMG_2015...     0
# 2731  ./cell_images/Uninfected/C51AP12thinF_IMG_2015...     0
# 2732  ./cell_images/Uninfected/C37BP2_thinF_IMG_2015...     0
# 2733  ./cell_images/Uninfected/C160P121ThinF_IMG_201...     0
# 2734  ./cell_images/Uninfected/C163P124ThinF_IMG_201...     0
# 2735  ./cell_images/Parasitized/C111P72ThinF_IMG_201...     1
# 2736  ./cell_images/Parasitized/C180P141NThinF_IMG_2...     1
# 2737  ./cell_images/Uninfected/C102P63ThinF_IMG_2015...     0
# 2738  ./cell_images/Uninfected/C126P87ThinF_IMG_2015...     0
# 2739  ./cell_images/Parasitized/C136P97ThinF_IMG_201...     1
# 2740  ./cell_images/Parasitized/C48P9thinF_IMG_20150...     1
# 2741  ./cell_images/Uninfected/C125P86ThinF_IMG_2015...     0
# 2742  ./cell_images/Parasitized/C184P145ThinF_IMG_20...     1
# 2743  ./cell_images/Parasitized/C59P20thinF_IMG_2015...     1
# 2744  ./cell_images/Uninfected/C113P74ThinF_IMG_2015...     0
# 2745  ./cell_images/Parasitized/C174P135NThinF_IMG_2...     1
# 2746  ./cell_images/Uninfected/C98P59ThinF_IMG_20150...     0
# 2747  ./cell_images/Parasitized/C137P98ThinF_IMG_201...     1
# 2748  ./cell_images/Parasitized/C103P64ThinF_IMG_201...     1
# 2749  ./cell_images/Parasitized/C78P39ThinF_IMG_2015...     1
# 2750  ./cell_images/Uninfected/C111P72ThinF_IMG_2015...     0
# 2751  ./cell_images/Parasitized/C51AP12thinF_IMG_201...     1
# 2752  ./cell_images/Parasitized/C91P52ThinF_IMG_2015...     1
# 2753  ./cell_images/Uninfected/C86P47ThinF_IMG_20150...     0
# 2754  ./cell_images/Uninfected/C105P66ThinF_IMG_2015...     0
#
# [2755 rows x 2 columns]

# %%
train_val_shuffle = train_val_df['label']

# %%
all_train = train_val_shuffle.shape[0]
positives_train = train_val_shuffle.sum()
negatives_train = all_train - positives_train



all_train, positives_train, negatives_train
# Out:
# (24803, 12396.0, 12407.0)

# %%
test_shuffle = test_df['label']

# %%
all_test = test_shuffle.shape[0]
positives_test = test_shuffle.sum()
negatives_test = all_test - positives_test
all_test, positives_test, negatives_test
# Out:
# (2755, 1383.0, 1372.0)

# %%
train_val_np = train_val_df['name'].values

# %% [markdown]
# # Copying the images in the right folder

# %%
for image_path in train_val_np:
    shutil.copy2(image_path,'./cell_images/'+ image_path.split('/')[-1])
    break # Remove break

# %%
test_np = test_df['name'].values

# %%
for image_path in test_np:
    shutil.copy2(image_path,'./cell_images/'+ image_path.split('/')[-1])
    break # Remove break

# %%
train_val_df['name'] = './cell_images/' + train_val_df['name'].str.split('/').str[-1].values

# %%
test_df['name'] = './cell_images/' + test_df['name'].str.split('/').str[-1].values

# %%
train_val_df
# Out:
#                                                     name label
# 0      ./cell_images/C228ThinF_IMG_20151112_142452_ce...     0
# 1      ./cell_images/C184P145ThinF_IMG_20151203_10272...     1
# 2      ./cell_images/C81P42ThinF_IMG_20150817_121113_...     1
# 3      ./cell_images/C171P132ThinF_IMG_20151119_15342...     0
# 4      ./cell_images/C84P45ThinF_IMG_20150818_101226_...     0
# 5      ./cell_images/C84P45ThinF_IMG_20150818_101412_...     0
# 6      ./cell_images/C51AP12thinF_IMG_20150724_154243...     0
# 7      ./cell_images/C63P24N_ThinF_IMG_20150818_14354...     1
# 8      ./cell_images/C116P77ThinF_IMG_20150930_171844...     1
# 9      ./cell_images/C50P11thinF_IMG_20150724_115141_...     0
# 10     ./cell_images/C183P144NThinF_IMG_20151201_2233...     0
# 11     ./cell_images/C140P101ThinF_IMG_20151005_21020...     1
# 12     ./cell_images/C159P120ThinF_IMG_20151115_18554...     1
# 13     ./cell_images/C136P97ThinF_IMG_20151005_142437...     1
# 14     ./cell_images/C217ThinF_IMG_20151106_141500_ce...     0
# 15     ./cell_images/C71P32_ThinF_IMG_20150813_162554...     0
# 16     ./cell_images/C4thin_original_IMG_20150608_165...     0
# 17     ./cell_images/C137P98ThinF_IMG_20151005_163218...     1
# 18     ./cell_images/C179P140ThinF_IMG_20151127_15335...     0
# 19     ./cell_images/C174P135NThinF_IMG_20151127_1353...     1
# 20     ./cell_images/C184P145ThinF_IMG_20151203_10332...     1
# 21     ./cell_images/C47P8thin_Original_Motic_IMG_201...     0
# 22     ./cell_images/C39P4thinF_original_IMG_20150622...     1
# 23     ./cell_images/C99P60ThinF_IMG_20150918_141857_...     1
# 24     ./cell_images/C187P148NThinF_IMG_20151203_1528...     0
# 25     ./cell_images/C144P105ThinF_IMG_20151015_16343...     0
# 26     ./cell_images/C233ThinF_IMG_20151112_160635_ce...     0
# 27     ./cell_images/C131P92ThinF_IMG_20151004_145302...     0
# 28     ./cell_images/C116P77ThinF_IMG_20150930_172112...     1
# 29     ./cell_images/C103P64ThinF_IMG_20150918_164331...     0
# ...                                                  ...   ...
# 24773  ./cell_images/C238NThinF_IMG_20151207_114653_c...     0
# 24774  ./cell_images/C116P77ThinF_IMG_20150930_171635...     1
# 24775  ./cell_images/C69P30N_ThinF_IMG_20150819_14014...     0
# 24776  ./cell_images/C118P79ThinF_IMG_20151002_105018...     1
# 24777  ./cell_images/C158P119ThinF_IMG_20151115_18315...     1
# 24778  ./cell_images/C180P141NThinF_IMG_20151201_1654...     1
# 24779  ./cell_images/C59P20thinF_IMG_20150803_113809_...     1
# 24780  ./cell_images/C135P96ThinF_IMG_20151005_124031...     0
# 24781  ./cell_images/C132P93ThinF_IMG_20151004_152045...     1
# 24782  ./cell_images/C131P92ThinF_IMG_20151004_150208...     1
# 24783  ./cell_images/C205ThinF_IMG_20151106_151711_ce...     0
# 24784  ./cell_images/C100P61ThinF_IMG_20150918_145422...     1
# 24785  ./cell_images/C133P94ThinF_IMG_20151004_154717...     1
# 24786  ./cell_images/C1_thinF_IMG_20150604_104942_cel...     0
# 24787  ./cell_images/C99P60ThinF_IMG_20150918_141857_...     1
# 24788  ./cell_images/C93P54ThinF_IMG_20150821_162901_...     1
# 24789  ./cell_images/C163P124ThinF_IMG_20151116_11192...     0
# 24790  ./cell_images/C180P141NThinF_IMG_20151201_1647...     1
# 24791  ./cell_images/C188P149ThinF_IMG_20151203_13431...     1
# 24792  ./cell_images/C45P6ThinF_IMG_20151130_160241_c...     0
# 24793  ./cell_images/C176P137NThinF_IMG_20151201_1206...     1
# 24794  ./cell_images/C92P53ThinF_IMG_20150821_150457_...     0
# 24795  ./cell_images/C168P129ThinF_IMG_20151118_16194...     0
# 24796  ./cell_images/C48P9thinF_IMG_20150721_164304_c...     1
# 24797  ./cell_images/C118P79ThinF_IMG_20151002_110725...     1
# 24798  ./cell_images/C83P44ThinF_IMG_20150817_134331_...     0
# 24799  ./cell_images/C55P16thinF_IMG_20150728_124508_...     0
# 24800  ./cell_images/C129P90ThinF_IMG_20151004_134520...     1
# 24801  ./cell_images/C56P17thinF_IMG_20150728_151330_...     0
# 24802  ./cell_images/C124P85ThinF_IMG_20151002_155026...     0
#
# [24803 rows x 2 columns]

# %%
test_df
# Out:
#                                                    name label
# 0     ./cell_images/C189P150ThinF_IMG_20151203_14130...     1
# 1     ./cell_images/C132P93ThinF_IMG_20151004_151941...     1
# 2     ./cell_images/C203ThinF_IMG_20151029_105443_ce...     0
# 3     ./cell_images/C68P29N_ThinF_IMG_20150819_13323...     1
# 4     ./cell_images/C141P102ThinF_IMG_20151005_21483...     1
# 5     ./cell_images/C78P39ThinF_IMG_20150606_104106_...     0
# 6     ./cell_images/C59P20thinF_IMG_20150803_111333_...     1
# 7     ./cell_images/C174P135NThinF_IMG_20151127_1354...     1
# 8     ./cell_images/C203ThinF_IMG_20151029_105443_ce...     0
# 9     ./cell_images/C213ThinF_IMG_20151106_112252_ce...     0
# 10    ./cell_images/C224ThinF_IMG_20151112_112334_ce...     0
# 11    ./cell_images/C7NthinF_IMG_20150611_105444_cel...     0
# 12    ./cell_images/C118P79ThinF_IMG_20151002_110942...     1
# 13    ./cell_images/C180P141NThinF_IMG_20151201_1637...     1
# 14    ./cell_images/C180P141NThinF_IMG_20151201_1647...     1
# 15    ./cell_images/C157P118ThinF_IMG_20151115_16402...     1
# 16    ./cell_images/C167P128ReThinF_IMG_20151201_105...     0
# 17    ./cell_images/C109P70ThinF_IMG_20150930_103113...     0
# 18    ./cell_images/C39P4thinF_original_IMG_20150622...     1
# 19    ./cell_images/C189P150ThinF_IMG_20151203_14111...     1
# 20    ./cell_images/C68P29N_ThinF_IMG_20150819_13323...     1
# 21    ./cell_images/C128P89ThinF_IMG_20151004_130408...     1
# 22    ./cell_images/C59P20thinF_IMG_20150803_112802_...     1
# 23    ./cell_images/C132P93ThinF_IMG_20151004_152505...     1
# 24    ./cell_images/C51AP12thinF_IMG_20150724_160140...     1
# 25    ./cell_images/C48P9thinF_IMG_20150721_161243_c...     0
# 26    ./cell_images/C39P4thinF_original_IMG_20150622...     1
# 27    ./cell_images/C1_thinF_IMG_20150604_105100_cel...     0
# 28    ./cell_images/C59P20thinF_IMG_20150803_112858_...     1
# 29    ./cell_images/C45P6ThinF_IMG_20151130_160409_c...     0
# ...                                                 ...   ...
# 2725  ./cell_images/C68P29N_ThinF_IMG_20150819_13462...     1
# 2726  ./cell_images/C160P121ThinF_IMG_20151116_09374...     0
# 2727  ./cell_images/C189P150ThinF_IMG_20151203_14140...     1
# 2728  ./cell_images/C81P42ThinF_IMG_20150817_120351_...     0
# 2729  ./cell_images/C111P72ThinF_IMG_20150930_112609...     1
# 2730  ./cell_images/C129P90ThinF_IMG_20151004_133329...     0
# 2731  ./cell_images/C51AP12thinF_IMG_20150724_154243...     0
# 2732  ./cell_images/C37BP2_thinF_IMG_20150620_133238...     0
# 2733  ./cell_images/C160P121ThinF_IMG_20151116_09310...     0
# 2734  ./cell_images/C163P124ThinF_IMG_20151116_11114...     0
# 2735  ./cell_images/C111P72ThinF_IMG_20150930_112430...     1
# 2736  ./cell_images/C180P141NThinF_IMG_20151201_1637...     1
# 2737  ./cell_images/C102P63ThinF_IMG_20150918_162300...     0
# 2738  ./cell_images/C126P87ThinF_IMG_20151004_105234...     0
# 2739  ./cell_images/C136P97ThinF_IMG_20151005_141946...     1
# 2740  ./cell_images/C48P9thinF_IMG_20150721_164031_c...     1
# 2741  ./cell_images/C125P86ThinF_IMG_20151004_102132...     0
# 2742  ./cell_images/C184P145ThinF_IMG_20151203_10311...     1
# 2743  ./cell_images/C59P20thinF_IMG_20150803_112733_...     1
# 2744  ./cell_images/C113P74ThinF_IMG_20150930_134429...     0
# 2745  ./cell_images/C174P135NThinF_IMG_20151127_1355...     1
# 2746  ./cell_images/C98P59ThinF_IMG_20150917_154235_...     0
# 2747  ./cell_images/C137P98ThinF_IMG_20151005_163251...     1
# 2748  ./cell_images/C103P64ThinF_IMG_20150918_165510...     1
# 2749  ./cell_images/C78P39ThinF_IMG_20150606_103413_...     1
# 2750  ./cell_images/C111P72ThinF_IMG_20150930_113610...     0
# 2751  ./cell_images/C51AP12thinF_IMG_20150724_155947...     1
# 2752  ./cell_images/C91P52ThinF_IMG_20150821_123116_...     1
# 2753  ./cell_images/C86P47ThinF_IMG_20150820_124259_...     0
# 2754  ./cell_images/C105P66ThinF_IMG_20150924_095716...     0
#
# [2755 rows x 2 columns]

# %% [markdown]
# # Saving the csv files with the image names

# %%
train_val_df.to_csv('./train_val_with_path.csv')
test_df.to_csv('./test_with_path.csv')

# %%
train_val_df['name'] = train_val_df['name'].str.split('/').str[-1].values
test_df['name'] =   test_df['name'].str.split('/').str[-1].values
train_val_df.to_csv('./train_val_no_path.csv')
test_df.to_csv('./test_no_path.csv')

# %%
train_val_df
# Out:
#                                                     name label
# 0              C228ThinF_IMG_20151112_142452_cell_85.png     0
# 1           C184P145ThinF_IMG_20151203_102721_cell_1.png     1
# 2           C81P42ThinF_IMG_20150817_121113_cell_180.png     1
# 3         C171P132ThinF_IMG_20151119_153425_cell_219.png     0
# 4            C84P45ThinF_IMG_20150818_101226_cell_45.png     0
# 5             C84P45ThinF_IMG_20150818_101412_cell_6.png     0
# 6          C51AP12thinF_IMG_20150724_154243_cell_101.png     0
# 7         C63P24N_ThinF_IMG_20150818_143544_cell_176.png     1
# 8          C116P77ThinF_IMG_20150930_171844_cell_101.png     1
# 9            C50P11thinF_IMG_20150724_115141_cell_27.png     0
# 10        C183P144NThinF_IMG_20151201_223357_cell_96.png     0
# 11        C140P101ThinF_IMG_20151005_210207_cell_171.png     1
# 12        C159P120ThinF_IMG_20151115_185541_cell_179.png     1
# 13         C136P97ThinF_IMG_20151005_142437_cell_128.png     1
# 14             C217ThinF_IMG_20151106_141500_cell_23.png     0
# 15          C71P32_ThinF_IMG_20150813_162554_cell_40.png     0
# 16      C4thin_original_IMG_20150608_165620_cell_208.png     0
# 17          C137P98ThinF_IMG_20151005_163218_cell_91.png     1
# 18        C179P140ThinF_IMG_20151127_153350_cell_110.png     0
# 19       C174P135NThinF_IMG_20151127_135342_cell_215.png     1
# 20        C184P145ThinF_IMG_20151203_103326_cell_150.png     1
# 21     C47P8thin_Original_Motic_IMG_20150714_093715_c...     0
# 22     C39P4thinF_original_IMG_20150622_110900_cell_1...     1
# 23           C99P60ThinF_IMG_20150918_141857_cell_44.png     1
# 24        C187P148NThinF_IMG_20151203_152841_cell_75.png     0
# 25        C144P105ThinF_IMG_20151015_163432_cell_227.png     0
# 26             C233ThinF_IMG_20151112_160635_cell_56.png     0
# 27         C131P92ThinF_IMG_20151004_145302_cell_115.png     0
# 28          C116P77ThinF_IMG_20150930_172112_cell_98.png     1
# 29         C103P64ThinF_IMG_20150918_164331_cell_172.png     0
# ...                                                  ...   ...
# 24773         C238NThinF_IMG_20151207_114653_cell_58.png     0
# 24774       C116P77ThinF_IMG_20150930_171635_cell_85.png     1
# 24775     C69P30N_ThinF_IMG_20150819_140143_cell_148.png     0
# 24776      C118P79ThinF_IMG_20151002_105018_cell_140.png     1
# 24777     C158P119ThinF_IMG_20151115_183157_cell_172.png     1
# 24778     C180P141NThinF_IMG_20151201_165453_cell_56.png     1
# 24779        C59P20thinF_IMG_20150803_113809_cell_20.png     1
# 24780       C135P96ThinF_IMG_20151005_124031_cell_70.png     0
# 24781      C132P93ThinF_IMG_20151004_152045_cell_118.png     1
# 24782      C131P92ThinF_IMG_20151004_150208_cell_141.png     1
# 24783         C205ThinF_IMG_20151106_151711_cell_153.png     0
# 24784      C100P61ThinF_IMG_20150918_145422_cell_167.png     1
# 24785      C133P94ThinF_IMG_20151004_154717_cell_132.png     1
# 24786          C1_thinF_IMG_20150604_104942_cell_185.png     0
# 24787         C99P60ThinF_IMG_20150918_141857_cell_9.png     1
# 24788       C93P54ThinF_IMG_20150821_162901_cell_198.png     1
# 24789      C163P124ThinF_IMG_20151116_111925_cell_20.png     0
# 24790    C180P141NThinF_IMG_20151201_164714_cell_179.png     1
# 24791     C188P149ThinF_IMG_20151203_134319_cell_192.png     1
# 24792         C45P6ThinF_IMG_20151130_160241_cell_71.png     0
# 24793     C176P137NThinF_IMG_20151201_120612_cell_22.png     1
# 24794       C92P53ThinF_IMG_20150821_150457_cell_126.png     0
# 24795      C168P129ThinF_IMG_20151118_161940_cell_20.png     0
# 24796         C48P9thinF_IMG_20150721_164304_cell_17.png     1
# 24797      C118P79ThinF_IMG_20151002_110725_cell_146.png     1
# 24798        C83P44ThinF_IMG_20150817_134331_cell_90.png     0
# 24799       C55P16thinF_IMG_20150728_124508_cell_101.png     0
# 24800      C129P90ThinF_IMG_20151004_134520_cell_111.png     1
# 24801        C56P17thinF_IMG_20150728_151330_cell_63.png     0
# 24802       C124P85ThinF_IMG_20151002_155026_cell_88.png     0
#
# [24803 rows x 2 columns]
